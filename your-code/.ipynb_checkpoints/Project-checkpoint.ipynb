# %% [markdown]
# ## Data Visualization Project

# %% [markdown]
# Me preocupa mucho el tema de movilidad y medio ambiente en la Ciudad de México, por lo que me propuse visualizar algunos de los datos públicos sobre estos temas. Primero, investigué en la mejor fuente para los datos que necesitaba: https://datos.cdmx.gob.mx/pages/home/. Posteriormente, decidí analizar los cambios en los límites de velocidad en las vialidades de la CDMX (2015-2019), así como los cambios de clasificación en las mismas.
#
# Como bonus, realicé un mapa de las relaciones entre los tiraderos de basura clandestinos y las zonas de mayor riesgo de precipitación, con la finalidad de encontrar los puntos geográficos en la ciudad con mayor probabilidad de inundación.

# %% [markdown]
# Importo librerías. Al final no utilicé algunas, pero por si las dudas.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import plotly as py
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns

# %% [markdown]
# Importo la base de datos de las vialidades de la CDMX, e inicié la exploración de los datos.

# %%
limite_velocidad = pd.read_csv('vialidades-de-la-ciudad-de-mexico.csv', sep=';')

# %%
limite_velocidad.head()
# Out:
#                        Geo Point  \
# 0   19.351710442, -99.0690930576
# 1  19.4065032037, -99.1063734226
# 2  19.4213409304, -99.1201092791
# 3   19.4960948813, -99.214227899
# 4  19.3543679679, -99.1899852361
#
#                                            Geo Shape  \
# 0  {"type": "LineString", "coordinates": [[-99.14...
# 1  {"type": "LineString", "coordinates": [[-99.13...
# 2  {"type": "LineString", "coordinates": [[-99.09...
# 3  {"type": "LineString", "coordinates": [[-99.20...
# 4  {"type": "LineString", "coordinates": [[-99.18...
#
#                   clasif_15  vel_15                 clasif_19  vel_19  \
# 0                  Eje Vial      50                  Eje Vial      50
# 1  Via de acceso controlado      80  Via de acceso controlado      80
# 2                  Eje Vial      50                  Eje Vial      50
# 3         Arteria principal      50         Arteria principal      50
# 4         Arteria principal      50         Arteria principal      50
#
#                                   Nombre  \
# 0    Eje 8 Sur Calzada Ermita Iztapalapa
# 1              Viaducto Rio de la Piedad
# 2  Eje 1 Sur Fray Servando Teres de Mier
# 3                   Calzada de las Armas
# 4          Eje 4 Poniente Av. Revolucion
#
#                                     Inicia                      Termina  \
# 0                       Calzada de Tlalpan     Calzada Ignacio Zaragoza
# 1                       Calzada de Tlalpan     Calzada Ignacio Zaragoza
# 2  Circuito Interior Jesus Galindo y Villa  Eje Central Lazaro Cardenas
# 3                    Calzada de la Naranja                     Herreros
# 4                                  Molinos  Eje 10 Sur Av. San Jeronimo
#
#    Shape_Leng Mixta
# 0   20.349900    No
# 1    6.435393    No
# 2   11.259555    No
# 3    4.890099    No
# 4    4.080091    Si

# %%
limite_velocidad.dtypes
# Out:
# Geo Point      object
# Geo Shape      object
# clasif_15      object
# vel_15          int64
# clasif_19      object
# vel_19          int64
# Nombre         object
# Inicia         object
# Termina        object
# Shape_Leng    float64
# Mixta          object
# dtype: object

# %%
limite_velocidad.isnull().sum()
# Out:
# Geo Point      0
# Geo Shape      0
# clasif_15      1
# vel_15         0
# clasif_19      0
# vel_19         0
# Nombre         0
# Inicia         0
# Termina        0
# Shape_Leng     0
# Mixta         33
# dtype: int64

# %% [markdown]
# Elimino las columnas que no necesito, en este caso la geolocalización. No mapearé esta base de datos.

# %%
limite_velocidad = limite_velocidad.drop(['Geo Point', 'Geo Shape'], axis=1)

# %% [markdown]
# Reordeno las columnas para mayor comodidad al analizar y graficar.

# %%
column_order = ['Nombre','Inicia','Termina','Shape_Leng','clasif_15','vel_15','clasif_19','vel_19','Mixta']
limite_velocidad = limite_velocidad[column_order]
limite_velocidad.head()
# Out:
#                                   Nombre  \
# 0    Eje 8 Sur Calzada Ermita Iztapalapa
# 1              Viaducto Rio de la Piedad
# 2  Eje 1 Sur Fray Servando Teres de Mier
# 3                   Calzada de las Armas
# 4          Eje 4 Poniente Av. Revolucion
#
#                                     Inicia                      Termina  \
# 0                       Calzada de Tlalpan     Calzada Ignacio Zaragoza
# 1                       Calzada de Tlalpan     Calzada Ignacio Zaragoza
# 2  Circuito Interior Jesus Galindo y Villa  Eje Central Lazaro Cardenas
# 3                    Calzada de la Naranja                     Herreros
# 4                                  Molinos  Eje 10 Sur Av. San Jeronimo
#
#    Shape_Leng                 clasif_15  vel_15                 clasif_19  \
# 0   20.349900                  Eje Vial      50                  Eje Vial
# 1    6.435393  Via de acceso controlado      80  Via de acceso controlado
# 2   11.259555                  Eje Vial      50                  Eje Vial
# 3    4.890099         Arteria principal      50         Arteria principal
# 4    4.080091         Arteria principal      50         Arteria principal
#
#    vel_19 Mixta
# 0      50    No
# 1      80    No
# 2      50    No
# 3      50    No
# 4      50    Si

# %% [markdown]
# Grafico dos histogramas, uno para cada año, de acuerdo a sus clasificaciones e histogramas.
#
# Una de las relaciones más relevantes es la reducción de las Vías de acceso controlado (o carreteras) con un límite de velocidad de 80 km/h.

# %%
fig = px.histogram(limite_velocidad, x="clasif_15", color='vel_15', title='Histograma | Límites de velocidad por vialidad, año 2015')
fig.show()
# Out:
# <div>
#
#
#             <div id="5f3c5520-ade9-408a-83c0-6aa7bb37e1dc" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5f3c5520-ade9-408a-83c0-6aa7bb37e1dc")) {
#                     Plotly.newPlot(
#                         '5f3c5520-ade9-408a-83c0-6aa7bb37e1dc',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "vel_15=50<br>clasif_15=%{x}<br>count=%{y}", "legendgroup": "vel_15=50", "marker": {"color": "#636efa"}, "name": "vel_15=50", "offsetgroup": "vel_15=50", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arter ...

# %%
fig = px.histogram(limite_velocidad, x="clasif_19", color='vel_19', title='Histograma | Límites de velocidad por vialidad, año 2019')
fig.show()
# Out:
# <div>
#
#
#             <div id="9e2d1cd0-b1dc-45ab-b6a9-1653601e9b70" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9e2d1cd0-b1dc-45ab-b6a9-1653601e9b70")) {
#                     Plotly.newPlot(
#                         '9e2d1cd0-b1dc-45ab-b6a9-1653601e9b70',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "vel_19=50<br>clasif_19=%{x}<br>count=%{y}", "legendgroup": "vel_19=50", "marker": {"color": "#636efa"}, "name": "vel_19=50", "offsetgroup": "vel_19=50", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria princi ...

# %% [markdown]
# Grafico box plots para los cuatro tipos de vialidad y la longitud de las mismas.
#
# Hay cierta delimitación real en la longitud de las vialidades, sin embargo, en las arterias principales los outsiders son muchos para su importancia.

# %%
fig = px.box(limite_velocidad, x="clasif_19", y='Shape_Leng', title='Box plot | Longitudes de los cuatro tipos de vailidades en la CDMX')
fig.show()
# Out:
# <div>
#
#
#             <div id="c3844535-8500-4f4b-8c46-879db44e9c83" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c3844535-8500-4f4b-8c46-879db44e9c83")) {
#                     Plotly.newPlot(
#                         'c3844535-8500-4f4b-8c46-879db44e9c83',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "clasif_19=%{x}<br>Shape_Leng=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Eje Vial", "Via de acceso controlado", "Eje Vial", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Via de acceso controlado", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Via de acceso controlado", "Via de acceso controlado", "Via de acceso controlado", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Via de acceso controlado", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Via de acceso controlado", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Via de acceso controlado", "Eje Vial", "Arteria principal", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Via de acceso controlado", "Via de acceso controlado", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Via de acceso controlado", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal" ...

# %%
fig = go.Figure(data=[
    go.Bar(name='2015', x=limite_velocidad.clasif_15, y=limite_velocidad.vel_15),
    go.Bar(name='2019', x=limite_velocidad.clasif_19, y=limite_velocidad.vel_19)
])

fig.update_layout(barmode='group', title='Gráfica de barras | Comparación entre total de vialidades en la CDMX, 2015-2019')
fig.show()
# Out:
# <div>
#
#
#             <div id="a852f88a-8dac-4bba-bc0f-35cc6b85651f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a852f88a-8dac-4bba-bc0f-35cc6b85651f")) {
#                     Plotly.newPlot(
#                         'a852f88a-8dac-4bba-bc0f-35cc6b85651f',
#                         [{"name": "2015", "type": "bar", "x": ["Eje Vial", "Via de acceso controlado", "Eje Vial", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Via de acceso controlado", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Via de acceso controlado", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Via de acceso controlado", "Eje Vial", "Arteria principal", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Arteria principal", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Carriles laterales", "Via de acceso controlado", "Via de acceso controlado", "Via de acceso controlado", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Arteria principal", "Eje Vial", "Eje Vial", null, "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Eje Vial", "Via de acceso controlado", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Arteria principal", "Via de acceso controlado", "Via de acceso controlado", "Arteria principal", "Carriles laterales", "Carriles laterales", "Via de acceso controlado", "Arteria principal", "Arteria principal", "Eje Vial", "Eje Vial", "Eje Vial", " ...

# %% [markdown]
# Gráfico scatter plots para comparar los límites de velocidad por tipo de vialidad y su longitud.
#
# Resulta más fácil visulizar las relaciones entre cierto límite de velocidad y la longitud a la que se puede conducir en tal camino. Es una gráfica que puede servir para encontrar coincidencias con los accidentes viales.

# %%
fig = px.scatter(limite_velocidad, x="vel_19", y="Shape_Leng", color="clasif_19", title='Scatter Plot | Límites de velocidad por tipo de vialidad y su longitud en la CDMX, año 2019')
fig.show()
# Out:
# <div>
#
#
#             <div id="5eff896d-262f-400c-bef1-eabd29b8bd90" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
# %% [markdown]
# ## Bonus

# %% [markdown]
# Importo dos bases de datos para comparar en un mapa el riesgo de precipitación por zonas y los tiraderos clandestinos en la CDMX.

# %%
riesgo_precipitacion = pd.read_csv('atlas-de-riesgo-precipitacion.csv', sep=';')

# %%
riesgo_precipitacion.head()
# Out:
#                         Geopoint  \
# 0  19.3849470814, -99.1438969068
# 1  19.2544657488, -99.0722615538
# 2    19.38126606, -99.1828865778
# 3  19.3867775197, -99.1794146708
# 4  19.2474326506, -99.0175796705
#
#                                             Geoshape    ID  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1436...   6.0
# 1  {"type": "Polygon", "coordinates": [[[-99.0748...   9.0
# 2  {"type": "Polygon", "coordinates": [[[-99.1808...  11.0
# 3  {"type": "Polygon", "coordinates": [[[-99.1766...  12.0
# 4  {"type": "Polygon", "coordinates": [[[-99.0210...  22.0
#
#               Fenómeno      Taxonomía     Rpve Intensidad  \
# 0  Hidrometeorológicos  Precipitación  Peligro       Bajo
# 1  Hidrometeorológicos  Precipitación  Peligro       Bajo
# 2  Hidrometeorológicos  Precipitación  Peligro      Medio
# 3  Hidrometeorológicos  Precipitación  Peligro      Medio
# 4  Hidrometeorológicos  Precipitación  Peligro   Muy Bajo
#
#                                          Descripción  \
# 0  Total acumulado de partículas liquidas o solid...
# 1  Total acumulado de partículas liquidas o solid...
# 2  Total acumulado de partículas liquidas o solid...
# 3  Total acumulado de partículas liquidas o solid...
# 4  Total acumulado de partículas liquidas o solid...
#
#                                               Fuente         Cvegeo  \
# 0  Dirección de Análisis de Riesgo de la SPCGIR, ...  0901400010488
# 1  Dirección de Análisis de Riesgo de la SPCGIR, ...  0901300011366
# 2  Dirección de Análisis de Riesgo de la SPCGIR, ...  0901400010562
# 3  Dirección de Análisis de Riesgo de la SPCGIR, ...  090140001037A
# 4  Dirección de Análisis de Riesgo de la SPCGIR, ...  0901300011192
#
#         Alcaldía           Entidad       Área mt2    Perímetro Period_Ret  \
# 0  Benito Juárez  Ciudad de México  230762.640075  2038.108726     5 años
# 1     Xochimilco  Ciudad de México  726107.192970  4849.029938     5 años
# 2  Benito Juárez  Ciudad de México  273658.477588  2334.776117     5 años
# 3  Benito Juárez  Ciudad de México  159743.594000  1937.902239     5 años
# 4     Xochimilco  Ciudad de México  837259.010624  5699.033668     5 años
#
#   Intens_Uni Intens_Num  int2
# 0         mm    54 a 60     2
# 1         mm    54 a 60     2
# 2         mm    60 a 64     3
# 3         mm    60 a 64     3
# 4         mm    41 a 54     1

# %%
riesgo_precipitacion.dtypes
# Out:
# Geopoint        object
# Geoshape        object
# ID             float64
# Fenómeno        object
# Taxonomía       object
# Rpve            object
# Intensidad      object
# Descripción     object
# Fuente          object
# Cvegeo          object
# Alcaldía        object
# Entidad         object
# Área mt2       float64
# Perímetro      float64
# Period_Ret      object
# Intens_Uni      object
# Intens_Num      object
# int2             int64
# dtype: object

# %%
riesgo_precipitacion.isnull().sum()
# Out:
# Geopoint       0
# Geoshape       0
# ID             0
# Fenómeno       0
# Taxonomía      0
# Rpve           0
# Intensidad     0
# Descripción    0
# Fuente         0
# Cvegeo         0
# Alcaldía       0
# Entidad        0
# Área mt2       0
# Perímetro      0
# Period_Ret     0
# Intens_Uni     0
# Intens_Num     0
# int2           0
# dtype: int64

# %%
riesgo_precipitacion[['Latitud','Longitud']] = riesgo_precipitacion['Geopoint'].str.split(expand=True)

# %%
riesgo_precipitacion['Latitud'] = riesgo_precipitacion['Latitud'].str.replace(',', '')
riesgo_precipitacion.head()
# Out:
#                         Geopoint  \
# 0  19.3849470814, -99.1438969068
# 1  19.2544657488, -99.0722615538
# 2    19.38126606, -99.1828865778
# 3  19.3867775197, -99.1794146708
# 4  19.2474326506, -99.0175796705
#
#                                             Geoshape    ID  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1436...   6.0
# 1  {"type": "Polygon", "coordinates": [[[-99.0748...   9.0
# 2  {"type": "Polygon", "coordinates": [[[-99.1808...  11.0
# 3  {"type": "Polygon", "coordinates": [[[-99.1766...  12.0
# 4  {"type": "Polygon", "coordinates": [[[-99.0210...  22.0
#
#               Fenómeno      Taxonomía     Rpve Intensidad  \
# 0  Hidrometeorológicos  Precipitación  Peligro       Bajo
# 1  Hidrometeorológicos  Precipitación  Peligro       Bajo
# 2  Hidrometeorológicos  Precipitación  Peligro      Medio
# 3  Hidrometeorológicos  Precipitación  Peligro      Medio
# 4  Hidrometeorológicos  Precipitación  Peligro   Muy Bajo
#
#                                          Descripción  \
# 0  Total acumulado de partículas liquidas o solid...
# 1  Total acumulado de partículas liquidas o solid...
# 2  Total acumulado de partículas liquidas o solid...
# 3  Total acumulado de partículas liquidas o solid...
# 4  Total acumulado de partículas liquidas o solid...
#
#                                               Fuente         Cvegeo  \
# 0  Dirección de Análisis de Riesgo de la SPCGIR, ...  0901400010488
# 1  Dirección de Análisis de Riesgo de la SPCGIR, ...  0901300011366
# 2  Dirección de Análisis de Riesgo de la SPCGIR, ...  0901400010562
# 3  Dirección de Análisis de Riesgo de la SPCGIR, ...  090140001037A
# 4  Dirección de Análisis de Riesgo de la SPCGIR, ...  0901300011192
#
#         Alcaldía           Entidad       Área mt2    Perímetro Period_Ret  \
# 0  Benito Juárez  Ciudad de México  230762.640075  2038.108726     5 años
# 1     Xochimilco  Ciudad de México  726107.192970  4849.029938     5 años
# 2  Benito Juárez  Ciudad de México  273658.477588  2334.776117     5 años
# 3  Benito Juárez  Ciudad de México  159743.594000  1937.902239     5 años
# 4     Xochimilco  Ciudad de México  837259.010624  5699.033668     5 años
#
#   Intens_Uni Intens_Num  int2        Latitud        Longitud
# 0         mm    54 a 60     2  19.3849470814  -99.1438969068
# 1         mm    54 a 60     2  19.2544657488  -99.0722615538
# 2         mm    60 a 64     3    19.38126606  -99.1828865778
# 3         mm    60 a 64     3  19.3867775197  -99.1794146708
# 4         mm    41 a 54     1  19.2474326506  -99.0175796705

# %%
riesgo_precipitacion = riesgo_precipitacion.drop(['Geopoint', 'Geoshape', 'Entidad', 'int2', 'Taxonomía', 'Fenómeno', 'Rpve', 'Fuente', 'ID'], axis=1)

# %%
column_order = ['Alcaldía','Cvegeo','Intensidad','Área mt2','Perímetro','Period_Ret','Intens_Num','Intens_Uni','Longitud','Latitud','Descripción']
riesgo_precipitacion = riesgo_precipitacion[column_order]
riesgo_precipitacion.head()
# Out:
#         Alcaldía         Cvegeo Intensidad       Área mt2    Perímetro  \
# 0  Benito Juárez  0901400010488       Bajo  230762.640075  2038.108726
# 1     Xochimilco  0901300011366       Bajo  726107.192970  4849.029938
# 2  Benito Juárez  0901400010562      Medio  273658.477588  2334.776117
# 3  Benito Juárez  090140001037A      Medio  159743.594000  1937.902239
# 4     Xochimilco  0901300011192   Muy Bajo  837259.010624  5699.033668
#
#   Period_Ret Intens_Num Intens_Uni        Longitud        Latitud  \
# 0     5 años    54 a 60         mm  -99.1438969068  19.3849470814
# 1     5 años    54 a 60         mm  -99.0722615538  19.2544657488
# 2     5 años    60 a 64         mm  -99.1828865778    19.38126606
# 3     5 años    60 a 64         mm  -99.1794146708  19.3867775197
# 4     5 años    41 a 54         mm  -99.0175796705  19.2474326506
#
#                                          Descripción
# 0  Total acumulado de partículas liquidas o solid...
# 1  Total acumulado de partículas liquidas o solid...
# 2  Total acumulado de partículas liquidas o solid...
# 3  Total acumulado de partículas liquidas o solid...
# 4  Total acumulado de partículas liquidas o solid...

# %%
tiraderos_clandestinos = pd.read_csv('tiraderos-clandestinos-al-cierre-de-2017.csv', sep=';')

# %%
tiraderos_clandestinos.dtypes
# Out:
# Column 1        int64
# FID_            int64
# id_sedema       int64
# no_alcaldi      int64
# alcaldia       object
# direccion_    float64
# tipo_tirad    float64
# calle          object
# no_ext        float64
# no_int        float64
# colonia        object
# entre_que_    float64
# longitud      float64
# latitud       float64
# geo_point      object
# dtype: object

# %%
tiraderos_clandestinos.isnull().sum()
# Out:
# Column 1         0
# FID_             0
# id_sedema        0
# no_alcaldi       0
# alcaldia         0
# direccion_    1129
# tipo_tirad    1129
# calle            0
# no_ext        1129
# no_int        1129
# colonia          7
# entre_que_    1129
# longitud         0
# latitud          0
# geo_point        0
# dtype: int64

# %%
tiraderos_clandestinos.drop(columns=['Column 1','FID_','direccion_','tipo_tirad','no_ext','no_int','entre_que_','geo_point'], inplace=True)

# %%
column_order = ['no_alcaldi','alcaldia','id_sedema','longitud','latitud','calle','colonia']
tiraderos_clandestinos = tiraderos_clandestinos[column_order]

# %%
tiraderos_clandestinos.head()
# Out:
#    no_alcaldi             alcaldia  id_sedema  longitud   latitud  \
# 0          10       Alvaro Obregon        409 -99.19734  19.39942
# 1          12              Tlalpan         66 -99.14130  19.30105
# 2          14        Benito Juarez        567 -99.13998  19.36772
# 3          17  Venustiano Carranza       1083 -99.12486  19.42981
# 4          17  Venustiano Carranza       1077 -99.12345  19.42520
#
#                                                calle  \
# 0  Calle Sur 114, Esquina Poniente 85, Colonia Co...
# 1  Calle Bordo Esquina Jazmines, Colonia Ejido Vi...
# 2  Municipio Libre Es2Quina Miraflores, Colonia P...
# 3  Calle De Manzanares Esquina Av. Circunvalacion...
# 4  Calle Carretones Esquina Rosario, Colonia Mora...
#
#                      colonia
# 0                       COVE
# 1  VIEJO EJIDO DE STA URSULA
# 2           PORTALES ORIENTE
# 3    COL. MERCED ZONA CENTRO
# 4    COL. MERCED ZONA CENTRO

# %% [markdown]
# Utilizo plotly.graph_objects y la función Scattergo. En esta caso selecciono las coordenadas de las zonas por cada base de datos. Para las zonas de precipitación agrego el tamaño de las mismas (área en metros cuadrados) y modifico la escala.
#
# Esta función de plotly no tiene una opción para mapear México en específico, ni ninguno de los estados, por lo que en el update_layout debo especificar las coordenadas de la CDMX.
#
# Aún me falta aprender más sobre esta librería para que el mapa sea más ameno. Pero los resultados sirven para encontrar zonas con mayor tendencia a inundarse debido al riesgo de precipitación ya los tiraderos de basura clandestinos.

# %%
fig = go.Figure()

fig.add_trace(go.Scattergeo(
    lon = tiraderos_clandestinos['longitud'],
    lat = tiraderos_clandestinos['latitud'],
    text = 'Tiradero clandestino en'+' '+tiraderos_clandestinos['alcaldia'],
    mode = 'markers',
    name = 'Tiraderos clandestinos',
    ))
fig.add_trace(go.Scattergeo(
    lon = riesgo_precipitacion['Longitud'],
    lat = riesgo_precipitacion['Latitud'],
    text = 'Riesgo de precipitación '+riesgo_precipitacion['Intens_Num']+' mm',
    marker = dict(size = riesgo_precipitacion['Área mt2']/100000, sizemode = 'area'),
    name = 'Zona de riesgo de precipitación',
    ))

fig.update_layout(
        title = 'Tiraderos clandestinos y zonas de riesgo de precipitación en la CDMX',
        geo = go.layout.Geo(
            scope='north america',
            lonaxis_range= [ -99.8332, -97.852362 ],
            lataxis_range= [ 19.0701465, 19.9326 ])
        )

fig.show()
# Out:
# <div>
#
#
#             <div id="c8506c7e-9db0-4a2c-a16c-0ae90bdaca81" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c8506c7e-9db0-4a2c-a16c-0ae90bdaca81")) {
#                     Plotly.newPlot(
#                         'c8506c7e-9db0-4a2c-a16c-0ae90bdaca81',
#                         [{"lat": [19.399420000000003, 19.30105, 19.367720000000002, 19.42981, 19.4252, 19.254360000000002, 19.203209899999997, 19.223079600000002, 19.2601375, 19.265981, 19.271643, 19.274005, 19.292944, 19.296997, 19.3002, 19.302147, 19.304102899999997, 19.30934, 19.30971, 19.3109, 19.31116, 19.31179, 19.31373, 19.31579, 19.31699, 19.3172, 19.324289999999998, 19.325209899999997, 19.32522, 19.32541, 19.3255424, 19.32708, 19.329050100000003, 19.32989, 19.32989, 19.33066, 19.331139999999998, 19.3323071, 19.3336544, 19.3336678, 19.3338, 19.3347, 19.335, 19.3369, 19.33768, 19.339029999999998, 19.3403978, 19.34382, 19.34404, 19.34404, 19.3442, 19.3452, 19.34551, 19.34609, 19.3478, 19.34781, 19.35066, 19.3515799, 19.35267, 19.35272, 19.353479999999998, 19.35609, 19.356117, 19.3584, 19.3584, 19.3584, 19.3584, 19.358439999999998, 19.36095, 19.3661, 19.36635, 19.366358399999996, 19.367070000000002, 19.36959, 19.37035, 19.3723986, 19.3724201, 19.37433, 19.37499, 19.37595, 19.37666, 19.376739999999998, 19.376776500000002, 19.377010000000002, 19.37795, 19.37858, 19.37969, 19.3804137, 19.380760000000002, 19.38146, 19.382479999999997, 19.38256, 