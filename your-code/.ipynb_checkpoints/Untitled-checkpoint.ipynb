# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn

# %%
data = pd.read_csv('../../train.csv')

# %%
data.dtypes
# Out:
# GameId                      int64
# PlayId                      int64
# Team                       object
# X                         float64
# Y                         float64
# S                         float64
# A                         float64
# Dis                       float64
# Orientation               float64
# Dir                       float64
# NflId                       int64
# DisplayName                object
# JerseyNumber                int64
# Season                      int64
# YardLine                    int64
# Quarter                     int64
# GameClock                  object
# PossessionTeam             object
# Down                        int64
# Distance                    int64
# FieldPosition              object
# HomeScoreBeforePlay         int64
# VisitorScoreBeforePlay      int64
# NflIdRusher                 int64
# OffenseFormation           object
# OffensePersonnel           object
# DefendersInTheBox         float64
# ...

# %%
data['WindSpeed'] = data['WindSpeed'].astype(str)
data['PlayerHeight'] = data['PlayerHeight'].astype(str)

# %%
dic_defensa={'SS':'Strong Safety','DE':'Defensive End','ILB':'Inside Line Backer','FS':'Free Safety','CB':'Corner Back','DT':'Defensive Tackle','DB':'Defensive Back','DL':'Defensive Line','MLB':'Middle Line Backer','NT':'Nose Tackle','LB':'Line Backer','OLB':'Offside Line Backer','S':'Safety','SAF':'Safety'}
dic_ofensa ={'WR':'Wide Receiver','TE':'Tight End','T':'Tackle Ofensivo','QB':'Quarterback','G':'Guard','C':'Centro','OG':'Offensive Guard','FB':'Full Back','HB':'Half Back','OT':'Offensive Tackle','RB':'Running Back'}
#list_ofensa =['WR','TE','T','QB','G','C','OG','FB','HB','OT','RB']

# %%
data['DefensiveTeam'] = np.where(data['PossessionTeam'] == data['HomeTeamAbbr'],data['VisitorTeamAbbr'],data['HomeTeamAbbr'])

# %%
#posiciones_off = list(dic_ofensa.keys())
#data.loc[[(x in list_ofensa) for x in data['Position']],'Def_Off'] = 'Off'
#data.loc[[(x not in list_ofensa) for x in data['Position']],'Def_Off'] = 'Def'

# %%
data['TeamPlayer'] = np.where(data['Team'] == 'away',data['VisitorTeamAbbr'],data['HomeTeamAbbr'])

# %%
data['TeamPlayer']
# Out:
# 0          KC
# 1          KC
# 2          KC
# 3          KC
# 4          KC
#          ...
# 509757    SEA
# 509758    SEA
# 509759    SEA
# 509760    SEA
# 509761    SEA
# Name: TeamPlayer, Length: 509762, dtype: object

# %%
jugadores = data[['NflId','DisplayName','JerseyNumber','PlayerHeight','PlayerWeight','PlayerBirthDate','PlayerCollegeName','Position','TeamPlayer']]

# %%
jugadores = jugadores.drop_duplicates(subset='NflId')

# %%
jugadores
# Out:
#           NflId      DisplayName  JerseyNumber PlayerHeight  PlayerWeight  \
# 0        496723       Eric Berry            29          6-0           212
# 1       2495116     Allen Bailey            97          6-3           288
# 2       2495493   Justin Houston            50          6-3           270
# 3       2506353  Derrick Johnson            56          6-3           245
# 4       2530794       Ron Parker            38          6-0           206
# ...         ...              ...           ...          ...           ...
# 504453  2535837   Austin Pasztor            68          6-7           305
# 506892  2534764  Gino Gradkowski            75          6-3           300
# 507565  2553706     Ryan Delaire            92          6-4           264
# 508672  2559264    Pasoni Tasini            65          6-3           307
# 508778  2558095    Malachi Dupre            15          6-2           196
#
#        PlayerBirthDate PlayerCollegeName Position TeamPlayer
# ...

# %%
def piesAmetros(x):
    medidas = x.split('-')
    return (float(medidas[0]) + float(medidas[1])/10)*0.3048

def librasAkilos (x):
    return x*0.453592

# %%
jugadores['PlayerHeight'] = jugadores['PlayerHeight'].map(piesAmetros)
jugadores['PlayerWeight'] = jugadores['PlayerWeight'].map(librasAkilos)

# %%
jugadores
# Out:
#           NflId      DisplayName  JerseyNumber  PlayerHeight  PlayerWeight  \
# 0        496723       Eric Berry            29       1.82880     96.161504
# 1       2495116     Allen Bailey            97       1.92024    130.634496
# 2       2495493   Justin Houston            50       1.92024    122.469840
# 3       2506353  Derrick Johnson            56       1.92024    111.130040
# 4       2530794       Ron Parker            38       1.82880     93.439952
# ...         ...              ...           ...           ...           ...
# 504453  2535837   Austin Pasztor            68       2.04216    138.345560
# 506892  2534764  Gino Gradkowski            75       1.92024    136.077600
# 507565  2553706     Ryan Delaire            92       1.95072    119.748288
# 508672  2559264    Pasoni Tasini            65       1.92024    139.252744
# 508778  2558095    Malachi Dupre            15       1.88976     88.904032
#
#        PlayerBirthDate PlayerCollegeName Position TeamPlayer
# ...

# %%
jugadores['PlayerBirthDate'] = jugadores['PlayerBirthDate'].map(lambda x: datetime.datetime.strptime(x,'%m/%d/%Y'))

# %%
jugadores
# Out:
#           NflId      DisplayName  JerseyNumber  PlayerHeight  PlayerWeight  \
# 0        496723       Eric Berry            29       1.82880     96.161504
# 1       2495116     Allen Bailey            97       1.92024    130.634496
# 2       2495493   Justin Houston            50       1.92024    122.469840
# 3       2506353  Derrick Johnson            56       1.92024    111.130040
# 4       2530794       Ron Parker            38       1.82880     93.439952
# ...         ...              ...           ...           ...           ...
# 504453  2535837   Austin Pasztor            68       2.04216    138.345560
# 506892  2534764  Gino Gradkowski            75       1.92024    136.077600
# 507565  2553706     Ryan Delaire            92       1.95072    119.748288
# 508672  2559264    Pasoni Tasini            65       1.92024    139.252744
# 508778  2558095    Malachi Dupre            15       1.88976     88.904032
#
#        PlayerBirthDate PlayerCollegeName Position TeamPlayer
# ...

# %%
now = datetime.datetime.today()
jugadores['Age'] = jugadores['PlayerBirthDate'].map(lambda x: int((now-x).days/365))

# %%
jugadores
# Out:
#           NflId      DisplayName  JerseyNumber  PlayerHeight  PlayerWeight  \
# 0        496723       Eric Berry            29       1.82880     96.161504
# 1       2495116     Allen Bailey            97       1.92024    130.634496
# 2       2495493   Justin Houston            50       1.92024    122.469840
# 3       2506353  Derrick Johnson            56       1.92024    111.130040
# 4       2530794       Ron Parker            38       1.82880     93.439952
# ...         ...              ...           ...           ...           ...
# 504453  2535837   Austin Pasztor            68       2.04216    138.345560
# 506892  2534764  Gino Gradkowski            75       1.92024    136.077600
# 507565  2553706     Ryan Delaire            92       1.95072    119.748288
# 508672  2559264    Pasoni Tasini            65       1.92024    139.252744
# 508778  2558095    Malachi Dupre            15       1.88976     88.904032
#
#        PlayerBirthDate PlayerCollegeName Position TeamPlayer  Age
# ...

# %%
#¿De que escuelas provienen más jugadores?
escuelas = jugadores.groupby(jugadores['PlayerCollegeName'])['NflId'].count()

# %%
escuelas = escuelas.sort_values(ascending=False)

# %%
total = escuelas.values.sum()
escuelas.values/total
escuelas[escuelas.values>10].plot(kind='bar',figsize=(50,20))

# %%
explode = [0]*len(escuelas[escuelas.values>25])
explode[0] = 0.1
fig1, ax1 = plt.subplots()
ax1.pie(escuelas[escuelas.values>25],explode=explode, labels=escuelas[escuelas.values>25].index, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# %%
alabama = jugadores[jugadores['PlayerCollegeName']=='Alabama']
florida = jugadores[jugadores['PlayerCollegeName']=='Florida']
OhioState = jugadores[jugadores['PlayerCollegeName']=='Ohio State']
FloridaState = jugadores[jugadores['PlayerCollegeName']=='Florida State']
Georgia = jugadores[jugadores['PlayerCollegeName']=='Georgia']

# %%
alabama_positions = alabama.groupby(alabama['Position'])['NflId'].count()
alabama_positions = alabama_positions.sort_values(ascending=False)
explode = [0]*len(alabama_positions.index)
explode[0] = 0.1
fig2, ax2 = plt.subplots()
ax2.pie(alabama_positions.values,explode=explode, labels=alabama_positions.index, autopct='%1.1f%%', shadow=True, startangle=90)
ax2.axis('equal')
plt.show()

# %%
alabama_teamsNfl = alabama.groupby(alabama['TeamPlayer'])['NflId'].count()
alabama_teamsNfl = alabama_teamsNfl.sort_values(ascending=False)
explode = [0]*len(alabama_teamsNfl.index)
explode[0] = 0.1
fig3, ax3 = plt.subplots()
ax3.pie(alabama_teamsNfl.values,explode=explode, labels=alabama_teamsNfl.index, autopct='%1.1f%%', shadow=True, startangle=90)
ax3.axis('equal')
plt.show()

# %%
'''''''''''
Los mejores pagados del 2019 de acuerdo con el promedio anual 
''''''''''''
