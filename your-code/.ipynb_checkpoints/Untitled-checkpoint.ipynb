# %%
import sys 
# !{sys.executable} -m pip install plotly==3 cufflinks

# %%
import plotly.plotly as py 
import cufflinks as cf
import pandas as pd 
import numpy as np

# %%
cf.go_offline()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#My project in data visualization seeks to get an overview about the economic growth globally with some data sets provided by ourworldindata.org
# 1. First we will see England's example of economic growth since 1270. 
# 2. Then we will look the The world economy over the last two millennia
# 3. After that we will take a look over Productivity which according to this data set, seems to be the driver of economic growth

# 4. World Bank data
# 4. GDP per capita in US-Dollar
# 4. Growth at the technological frontier
# 5. Catch up growth can be fast

# 6. Urbanization and prosperity seems to be strongly correlated. 

# 7. Retirement becomes possible when people get richer

# 8. Access to financial services

# %%
# 1. England's example of economic growth since 1270. 

growth_df = pd.read_csv('GDP-per-capita-in-the-uk-since-1270.csv')
#growth_df[:10]



growth2_df = growth_df.drop(['Entity', 'Code'], axis=1)

growth2_df.set_index('Year', inplace=True)

growth2_df
# Out:
#       Real GDP per capita (BoE (2017)) (£)
# Year
# 1270                            805.922956
# 1271                            796.299377
# 1272                            824.894942
# 1273                            776.853595
# 1274                            772.753576
# 1275                            881.908508
# 1276                            774.897510
# 1277                            826.156697
# 1278                            855.207272
# 1279                            708.723165
# 1280                            715.382607
# 1281                            755.873359
# 1282                            729.018634
# 1283                            689.125046
# 1284                            708.602547
# 1285                            713.418886
# 1286                            699.304166
# 1287                            761.098199
# 1288                            733.676532
# 1289                            673.108708
# 1290                            678.764088
# ...

# %%
# England is an global example of economic growth since it is the first country that reached economic prosperity for most of its population. Seems remarkable that after the industrial revolution growth was not as exponential as after the World War Two, where we can see a continous growth only stopped at certain periods, the most recent at 2010.  

growth2_df.iplot(kind='line', xTitle='Year', yTitle='Income in pounds',
                title="<b>GDP per capita in England since 1270</b> <br> <i>Adjusted for inflation and measured in British Pounds in 2013 prices</i>")
# Out:
# <div id="23235841-e11a-4301-9dce-90115ced7fe8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("23235841-e11a-4301-9dce-90115ced7fe8", [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Real GDP per capita (BoE (2017)) (\u00a3)", "text": "", "x": [1270.0, 1271.0, 1272.0, 1273.0, 1274.0, 1275.0, 1276.0, 1277.0, 1278.0, 1279.0, 1280.0, 1281.0, 1282.0, 1283.0, 1284.0, 1285.0, 1286.0, 1287.0, 1288.0, 1289.0, 1290.0, 1291.0, 1292.0, 1293.0, 1294.0, 1295.0, 1296.0, 1297.0, 1298.0, 1299.0, 1300.0, 1301.0, 1302.0, 1303.0, 1304.0, 1305.0, 1306.0, 1307.0, 1308.0, 1309.0, 1310.0, 1311.0, 1312.0, 1313.0, 1314.0, 1315.0, 1316.0, 1317.0, 1318.0, 1319.0, 1320.0, 1321.0, 1322.0, 1323.0, 1324.0, 1325.0, 1326.0, 1327.0, 1328.0, 1329.0, 1330.0, 1
# ...

# %%
gdp_last_two_millennia = pd.read_csv('world-gdp-over-the-last-two-millennia.csv')
gdp_last_two_millennia
# Out:
#    Entity      Code  Year      (int.-$)
# 0   World  OWID_WRL     1  1.827410e+11
# 1   World  OWID_WRL  1000  2.101447e+11
# 2   World  OWID_WRL  1500  4.305273e+11
# 3   World  OWID_WRL  1600  5.744687e+11
# 4   World  OWID_WRL  1700  6.433229e+11
# 5   World  OWID_WRL  1820  1.202361e+12
# 6   World  OWID_WRL  1870  1.923917e+12
# 7   World  OWID_WRL  1900  3.418754e+12
# 8   World  OWID_WRL  1913  4.738676e+12
# 9   World  OWID_WRL  1940  7.806369e+12
# 10  World  OWID_WRL  1950  9.251063e+12
# 11  World  OWID_WRL  1951  9.795631e+12
# 12  World  OWID_WRL  1952  1.024870e+13
# 13  World  OWID_WRL  1953  1.076485e+13
# 14  World  OWID_WRL  1954  1.113282e+13
# 15  World  OWID_WRL  1955  1.184244e+13
# 16  World  OWID_WRL  1956  1.239932e+13
# 17  World  OWID_WRL  1957  1.287120e+13
# 18  World  OWID_WRL  1958  1.328451e+13
# 19  World  OWID_WRL  1959  1.389334e+13
# 20  World  OWID_WRL  1960  1.462043e+13
# 21  World  OWID_WRL  1961  1.512755e+13
# ...

# %%
gdp_last_two_millennia_df = gdp_last_two_millennia.drop(['Code', 'Entity'], axis=1)


gdp_last_two_millennia_df.set_index('Year', inplace=True)

gdp_last_two_millennia_df
# Out:
#           (int.-$)
# Year
# 1     1.827410e+11
# 1000  2.101447e+11
# 1500  4.305273e+11
# 1600  5.744687e+11
# 1700  6.433229e+11
# 1820  1.202361e+12
# 1870  1.923917e+12
# 1900  3.418754e+12
# 1913  4.738676e+12
# 1940  7.806369e+12
# 1950  9.251063e+12
# 1951  9.795631e+12
# 1952  1.024870e+13
# 1953  1.076485e+13
# 1954  1.113282e+13
# 1955  1.184244e+13
# 1956  1.239932e+13
# 1957  1.287120e+13
# 1958  1.328451e+13
# 1959  1.389334e+13
# 1960  1.462043e+13
# 1961  1.512755e+13
# 1962  1.584037e+13
# 1963  1.652882e+13
# 1964  1.772743e+13
# 1965  1.865562e+13
# 1966  1.967278e+13
# 1967  2.040481e+13
# 1968  2.152760e+13
# 1969  2.271548e+13
# ...            ...
# 1986  4.123197e+13
# 1987  4.281290e+13
# 1988  4.464965e+13
# 1989  4.607684e+13
# 1990  4.704380e+13
# 1991  4.765090e+13
# 1992  4.848510e+13
# 1993  4.941550e+13
# 1994  5.088660e+13
# 1995  5.257660e+13
# 1996  5.460520e+13
# 1997  5.677210e+13
# 1998  5.815950e+13
# 1999  6.024750e+13
# 2000  6.310090e+13
# ...

# %%
gdp_last_two_millennia_df.describe()
# Out:
#            (int.-$)
# count  7.600000e+01
# mean   3.787252e+13
# std    2.941472e+13
# min    1.827410e+11
# 25%    1.374114e+13
# 50%    3.217197e+13
# 75%    5.514692e+13
# max    1.081200e+14

# %%
gdp_last_two_millennia_df.iplot(kind='bar', xTitle='Year', yTitle='Income in US Dollars',
                title="<b>GDP Per Capita In The Last Two Millenia</b>")
#we can see that there is clearly an exponential increase in the world GDP per Capita from the late 1800.
# Out:
# <div id="51735406-bede-4487-965e-1114869b2fb8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("51735406-bede-4487-965e-1114869b2fb8", [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": " (int.-$)", "orientation": "v", "text": "", "x": [1.0, 1000.0, 1500.0, 1600.0, 1700.0, 1820.0, 1870.0, 1900.0, 1913.0, 1940.0, 1950.0, 1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0, 1958.0, 1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0,
# ...

# %%
import seaborn as sns
urba_df = pd.read_csv('urbanization-vs-gdp.csv')

urba_df.fillna('0', inplace=True)
urba_df[["GDP per capita (2011 int-$) ($)", "Share of population living in urban areas (%)"]]  = urba_df[["GDP per capita (2011 int-$) ($)", "Share of population living in urban areas (%)"]].astype(int)

ur_b = urba_df.groupby('Entity').mean()
ur_b
# Out:
#                                               Year  \
# Entity
# Afghanistan                            1975.549296
# Africa                                 1973.662162
# Africa Maddison definition             1983.000000
# Albania                                1958.009434
# Algeria                                1971.722222
# American Samoa                         1970.840000
# Andorra                                1977.985507
# Angola                                 1977.442857
# Anguilla                               1977.985507
# Antarctica                             1700.000000
# Antigua and Barbuda                    1970.064935
# Argentina                              1941.911565
# Armenia                                1977.985507
# Aruba                                  1977.985507
# Asia                                   1973.662162
# Asia-Stan                              1700.000000
# Australia                              1916.311558
# ...

# %%
ur_b.boxplot(column="Share of population living in urban areas (%)");

# %%
import seaborn as sns
sns.scatterplot(x="GDP per capita (2011 int-$) ($)", y="Share of population living in urban areas (%)", data=ur_b)

# %%
urb_table = pd.crosstab(index=ur_b["Share of population living in urban areas (%)"], columns=ur_b["GDP per capita (2011 int-$) ($)"])
urb_table
# Out:
# GDP per capita (2011 int-$) ($)                0.000000      616.657143    \
# Share of population living in urban areas (%)
# 0.000000                                                  9             0
# 2.400000                                                  1             0
# 2.800000                                                  1             0
# 3.666667                                                  1             0
# 4.222222                                                  1             0
# 4.777778                                                  1             0
# 4.800000                                                  1             0
# 4.942029                                                  0             0
# 5.800000                                                  1             0
# 6.200000                                                  1             0
# 6.400818                                                  0             0
# ...
